# %%
import os
import PIL
from PIL import Image
import glob
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
g=os.getcwd()+"\\"+"*.jpg"
print(g)
new_width  = 200
new_height = 200
size=(new_width, new_height)
new_RGB=3
X_data = np.empty([20,200,200,3], dtype = int)
files = glob.glob (g)
m=0
for myFile in files:
    #print(myFile)
    image = Image.open(myFile)
    
    image=image.resize(size)
    X_data[m]=image
    m=m+1
arr=np.asarray(X_data)
    


   

    

    
    
    

    
    
    
    
    
    
    
#print('X_data shape:', np.array(X_data).shape)
# Out:
# C:\Users\DELL\Piaic\Q2\Untitled Folder\*.jpg

# %%
for img in X_data:
    plt.figure()
    plt.imshow(img)
   #print( img)
